# %% [markdown]
# <a href="https://colab.research.google.com/github/AFTC000/DetectorDeObjetos/blob/main/Detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/drive/MyDrive/data.zip  -d  /content/
# Out:
# Archive:  /content/drive/MyDrive/data.zip
# replace /content/data/data.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15921, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 15921 (delta 16), reused 22 (delta 8), pack-reused 15880
# Receiving objects: 100% (15921/15921), 14.66 MiB | 16.23 MiB/s, done.
# Resolving deltas: 100% (10911/10911), done.

# %%
# %cd yolov5
# %pip install -qr requirements.txt
# %pip install roboflow
# Out:
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 20.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 8.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.7 MB/s eta 0:00:00
# ...

# %%
import torch
import os
from IPython.display import Image, clear_output

# %%
# %ls
# !python train.py --img 132 --batch 20 --data ../data/data.yaml --epoch 50 --weights yolov5l.pt --cache
# Out:
# benchmarks.py    detect.py   __pycache__/      segment/        val.py
# CITATION.cff     export.py   README.md         setup.cfg
# classify/        hubconf.py  README.zh-CN.md   train.py
# CONTRIBUTING.md  LICENSE     requirements.txt  tutorial.ipynb
# data/            models/     runs/             utils/
# train: weights=yolov5l.pt, cfg=, data=../data/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=20, imgsz=132, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...
